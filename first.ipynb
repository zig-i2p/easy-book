# %%
import pendulum
dt_moscow = pendulum.datetime(2021, 2, 3, tz='Europe/Moscow')
dt_vancouver = pendulum.datetime(2021, 2, 3, tz='America/Vancouver')

print(dt_vancouver.diff(dt_moscow).in_hours())
# Out:
# 11

# %%
open('server_config.py', 'r')
# Out:
# <_io.TextIOWrapper name='server_config.py' mode='r' encoding='UTF-8'>

# %%
f = open('server_config.py')
f.read(1)
f.read()
# Out:
# ' Configuration file for jupyter-server.\n\n#------------------------------------------------------------------------------\n# Application(SingletonConfigurable) configuration\n#------------------------------------------------------------------------------\n## This is an application.\n\n## The date format used by logging formatters for %(asctime)s\n#  Default: \'%Y-%m-%d %H:%M:%S\'\n# c.Application.log_datefmt = \'%Y-%m-%d %H:%M:%S\'\n\n## The Logging format template\n#  Default: \'[%(name)s]%(highlevel)s %(message)s\'\n# c.Application.log_format = \'[%(name)s]%(highlevel)s %(message)s\'\n\n## Set the log level by value or name.\n#  Choices: any of [0, 10, 20, 30, 40, 50, \'DEBUG\', \'INFO\', \'WARN\', \'ERROR\', \'CRITICAL\']\n#  Default: 30\n# c.Application.log_level = 30\n\n## Instead of starting the Application, dump configuration to stdout\n#  Default: False\n# c.Application.show_config = False\n\n## Instead of starting the Application, dump configuration to stdout (as JSON)\n# 
# ...

# %%
f = open('server_config.py')
for line in f:
    line

# %%
l = [str(i)+str(i-1) for i in range(20)]
l

f = open('text.txt', 'w')
for index in l:
    f.write(index + '\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-81909f40b6a6> in <module>
#       4 f = open('text.txt', 'w')
#       5 for index in l:
# ----> 6     f.write(index + '\n')
#       7     f.close()
#
# ValueError: I/O operation on closed file.

# %%
 f.close()

# %%
f = open('text.txt', 'r')
l = [line.strip() for line in f]
l
f.close()
